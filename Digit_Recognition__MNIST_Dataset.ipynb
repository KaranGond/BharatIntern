# %% [markdown]
# <a href="https://colab.research.google.com/github/KaranGond/BharatIntern/blob/main/Digit_Recognition__MNIST_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# Load and preprocess the MNIST dataset
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

X_train_full = X_train_full.reshape(-1, 28, 28, 1).astype('float32') / 255.0
X_test = X_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

y_train_full = to_categorical(y_train_full, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# Split the training data into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.1, random_state=42)

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with training and validation data
model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_valid, y_valid))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Epoch 1/10
# 844/844 [==============================] - 19s 7ms/step - loss: 0.3345 - accuracy: 0.8967 - val_loss: 0.0665 - val_accuracy: 0.9795
# Epoch 2/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1033 - accuracy: 0.9703 - val_loss: 0.0435 - val_accuracy: 0.9878
# Epoch 3/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0750 - accuracy: 0.9791 - val_loss: 0.0362 - val_accuracy: 0.9908
# Epoch 4/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0604 - accuracy: 0.9836 - val_loss: 0.0385 - val_accuracy: 0.9902
# Epoch 5/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0512 - accuracy: 0.9856 - val_loss: 0.0314 - val_accuracy: 0.9905
# Epoch 6/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0434 - accuracy: 0.9877 - val_loss: 0.0274 - val_accuracy: 0.9917
# Epoch 7/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0361 - accuracy: 0.9892 - val_loss: 0.0295 - val_accuracy: 0.9920
# Epoch 8/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0330 - accuracy: 0.9905 - val_loss: 0.0375 - val_accuracy: 0.9908
# Epoch 9/10
# 844/844 [==============================] - 5s 6ms/step - loss: 0.0277 - accuracy: 0.9920 - val_loss: 0.0323 - val_accuracy: 0.9908
# Epoch 10/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 0.0330 - val_accuracy: 0.9908
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0255 - accuracy: 0.9930
# Test Loss: 0.0255
# Test Accuracy: 0.9930

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the MNIST dataset
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

X_train_full = X_train_full.reshape(-1, 28, 28, 1).astype('float32') / 255.0
X_test = X_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

y_train_full = to_categorical(y_train_full, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# Split the training data into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.1, random_state=42)

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with training and validation data
model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_valid, y_valid))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Make predictions on the test set
predictions = model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Visualize a few examples
num_examples = 10
indices = np.random.choice(len(X_test), num_examples, replace=False)

for idx in indices:
    plt.figure()
    plt.imshow(X_test[idx].reshape(28, 28), cmap='gray')
    plt.title(f"True Label: {true_labels[idx]}, Predicted Label: {predicted_labels[idx]}")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/10
# 844/844 [==============================] - 9s 6ms/step - loss: 0.3380 - accuracy: 0.8947 - val_loss: 0.0655 - val_accuracy: 0.9807
# Epoch 2/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1075 - accuracy: 0.9694 - val_loss: 0.0417 - val_accuracy: 0.9882
# Epoch 3/10
# 844/844 [==============================] - 5s 5ms/step - loss: 0.0766 - accuracy: 0.9782 - val_loss: 0.0392 - val_accuracy: 0.9875
# Epoch 4/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0613 - accuracy: 0.9828 - val_loss: 0.0361 - val_accuracy: 0.9895
# Epoch 5/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0511 - accuracy: 0.9848 - val_loss: 0.0325 - val_accuracy: 0.9913
# Epoch 6/10
# 844/844 [==============================] - 5s 5ms/step - loss: 0.0414 - accuracy: 0.9880 - val_loss: 0.0310 - val_accuracy: 0.9910
# Epoch 7/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0364 - accuracy: 0.9894 - val_loss: 0.0328 - val_accuracy: 0.9908
# Epoch 8/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0318 - accuracy: 0.9907 - val_loss: 0.0397 - val_accuracy: 0.9895
# Epoch 9/10
# 844/844 [==============================] - 5s 6ms/step - loss: 0.0261 - accuracy: 0.9920 - val_loss: 0.0373 - val_accuracy: 0.9890
# Epoch 10/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0243 - accuracy: 0.9926 - val_loss: 0.0309 - val_accuracy: 0.9912
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0248 - accuracy: 0.9921
# Test Loss: 0.0248
# Test Accuracy: 0.9921
# 313/313 [==============================] - 1s 2ms/step

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the MNIST dataset
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()

X_train_full = X_train_full.reshape(-1, 28, 28, 1).astype('float32') / 255.0
X_test = X_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

y_train_full = to_categorical(y_train_full, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# Split the training data into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size=0.1, random_state=42)

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with training and validation data
model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_valid, y_valid))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Visualize examples of each digit
num_examples_per_digit = 10
for digit in range(10):
    digit_indices = np.where(np.argmax(y_test, axis=1) == digit)[0]
    selected_indices = digit_indices[:num_examples_per_digit]

    plt.figure(figsize=(15, 1))
    for i, idx in enumerate(selected_indices):
        plt.subplot(1, num_examples_per_digit, i + 1)
        plt.imshow(X_test[idx].reshape(28, 28), cmap='gray')
        plt.title(f"Label: {digit}")
        plt.axis('off')
    plt.show()

# Make predictions on a subset of the test set
num_examples_to_predict = 10
indices_to_predict = np.random.choice(len(X_test), num_examples_to_predict, replace=False)
predictions = model.predict(X_test[indices_to_predict])
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test[indices_to_predict], axis=1)

# Visualize predictions
for i in range(num_examples_to_predict):
    plt.figure()
    plt.imshow(X_test[indices_to_predict[i]].reshape(28, 28), cmap='gray')
    plt.title(f"True Label: {true_labels[i]}, Predicted Label: {predicted_labels[i]}")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/10
# 844/844 [==============================] - 8s 5ms/step - loss: 0.3399 - accuracy: 0.8963 - val_loss: 0.0671 - val_accuracy: 0.9807
# Epoch 2/10
# 844/844 [==============================] - 5s 6ms/step - loss: 0.1027 - accuracy: 0.9711 - val_loss: 0.0512 - val_accuracy: 0.9853
# Epoch 3/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0742 - accuracy: 0.9786 - val_loss: 0.0403 - val_accuracy: 0.9892
# Epoch 4/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0594 - accuracy: 0.9834 - val_loss: 0.0338 - val_accuracy: 0.9905
# Epoch 5/10
# 844/844 [==============================] - 5s 5ms/step - loss: 0.0473 - accuracy: 0.9864 - val_loss: 0.0374 - val_accuracy: 0.9893
# Epoch 6/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0417 - accuracy: 0.9887 - val_loss: 0.0405 - val_accuracy: 0.9883
# Epoch 7/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0356 - accuracy: 0.9899 - val_loss: 0.0307 - val_accuracy: 0.9923
# Epoch 8/10
# 844/844 [==============================] - 5s 6ms/step - loss: 0.0308 - accuracy: 0.9912 - val_loss: 0.0310 - val_accuracy: 0.9905
# Epoch 9/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0269 - accuracy: 0.9922 - val_loss: 0.0384 - val_accuracy: 0.9897
# Epoch 10/10
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0248 - accuracy: 0.9924 - val_loss: 0.0394 - val_accuracy: 0.9905
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0289 - accuracy: 0.9924
# Test Loss: 0.0289
# Test Accuracy: 0.9924
# 1/1 [==============================] - 0s 170ms/step
